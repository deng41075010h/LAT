# %% [markdown]
# 從線上匯入csv

# %%
import pandas as pd

# Read CSV file from URL
url = "https://ws.moe.edu.tw/001/Upload/4/relfile/0/5051/8f8f0105-b5bb-424e-9921-acd69358eda6.csv"
df = pd.read_csv(url, encoding='UTF-8')
df
# Out:
#       開課年度  開課學期      校名         課程名稱      系所名稱   年級  學分數         學制 必選修  \
# 0      108     1  國立清華大學      共善的社會設計    通識教育中心  NaN  2.0  學士班(含第二部)  選修
# 1      108     1  國立清華大學    生態體系與全球變遷    通識教育中心  NaN  2.0  學士班(含第二部)  必修
# 2      108     1  國立清華大學    生態體系與全球變遷    通識教育中心  NaN  2.0  學士班(含第二部)  必修
# 3      108     1  國立清華大學  衍生性金融商品實務研討  計量財務金融學系  NaN  2.0  學士班(含第二部)  選修
# 4      108     1    銘傳大學        音樂與生活    通識教育中心  NaN  2.0  學士班(含第二部)  選修
# ...    ...   ...     ...          ...       ...  ...  ...        ...  ..
# 1291   108     2    亞洲大學       整合行銷研究    資訊傳播學系    1  3.0        碩士班  選修
# 1292   108     2    亞洲大學         金融市場    財務金融學系    1  3.0    碩士班在職專班  必修
# 1293   108     2    亞洲大學    諮商駐地實習(二)      心理學系    3  3.0        碩士班  選修
# 1294   108     2    東海大學   大數據技術平台與應用    資訊工程學系    0  3.0        碩士班  選修
# 1295   108     2    東海大學    巨量資料分析與應用    資訊管理學系    0  3.0        碩士班  選修
#
#       總修課人數
# 0        47
# 1       120
# 2        66
# 3        28
# 4        60
# ...

# %% [markdown]
# big5編碼匯入

# %%
#載入csv
import pandas as pd

df = pd.read_csv('109-111年臺北市民免費數位訓練情形.csv', encoding='big5')

df
# Out:
#       年度   序號  行政區                                            上課地點     上課日期  \
# 0    109    1  文山區                                         文山區公民會館  1090106
# 1    109    2  文山區                                         文山區公民會館  1090106
# 2    109    3  文山區                                         文山區公民會館  1090113
# 3    109    4  大安區                                        社會創新實驗中心  1090205
# 4    109    5  大安區                                        社會創新實驗中心  1090205
# ..   ...  ...  ...                                             ...      ...
# 332  111  333  中正區       臺北市中正區文祥里杭州南路1段131巷22號\n (臺北市中正區文祥社區發展協會)  1111130
# 333  111  334  北投區                      台北市北投區泉源里東昇路80號\n (頂湖活動中心)  1111130
# 334  111  335  北投區             台北市北投區振華里裕民一路40巷37號1樓\n (振華里里民活動中心)  1111130
# 335  111  336  內湖區                台北市內湖區內湖里成功路四段50號2樓\n (巨匠電腦內湖認證)  1111130
# 336  111  337  中山區  臺北市中山區金泰里敬業三路162巷109號1樓\n (財團法人基督教台灣信義會(大直真理堂)  1111130
#
#             上課時間        課程名稱  人數
# ...

# %%
#載入csv
import pandas as pd

df = pd.read_csv('107年課程報名人數 .csv', encoding='big5')

df
# Out:
#      課程主類別 課程副類別 課程次類別                           課程名稱  報名人次總計
# 0      人文類  人文藝術  手作工藝     "["原住民"]"視覺設計系列"－"文化創意夢想起飛    2008
# 1      人文類  人文藝術  手作工藝  "["原住民"]"視覺設計系列"－"傳統工藝技術與商品結合    8183
# 2      人文類  人文藝術  手作工藝       "["原住民"]"蔡宜錦"－"時尚原住民特色產品    4004
# 3      人文類  人文藝術  手作工藝    "["原住民"]"盧春華"－"彩繪藝術與原住民創意商品    2689
# 4      人文類  人文藝術  手作工藝          "["環境教育"]"環保 健康 生活手工皂    3461
# ...    ...   ...   ...                            ...     ...
# 1838   職訓類  餐飲製作  烘焙食品  樂活點心清爽有味"－"蒸烤布丁"－"臺北市職能發展學院提供     631
# 1839   職訓類  餐飲製作  烘焙食品   樂活點心清爽有味"－"蘿蔔糕"－"臺北市職能發展學院提供     511
# 1840   職訓類  餐飲製作  烘焙食品             鬆餅裝飾"－"臺北市職能發展學院提供     459
# 1841   職訓類  餐飲製作  飲料調製             基礎調酒"－"臺北市職能發展學院提供     436
# 1842   職訓類  餐飲製作  飲料調製       義式咖啡基礎拉花技巧"－"臺北市職能發展學院提供    1267
#
# [1843 rows x 5 columns]
